# %%
# Import libraries for data manipulation
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# Import libraries for regression modeling
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %%
# Import data from csv file
df = pd.read_csv('../source_data/housing_data_cleaned.csv')

# data = df[['garage_spaces',
#            'interior_condition',
#            'market_value',
#            'sale_price',
#            'total_area',
#            'total_livable_area']]

df = df.select_dtypes(exclude=object)
df
# Out:
#           id  census_tract   depth  exempt_building  exempt_land  \
# 0          1           241   67.00            49200            0
# 1          2           201   70.00                0            0
# 2          3           281   95.50                0            0
# 3          4           293  112.50                0            0
# 4          5            62   79.00                0            0
# ...      ...           ...     ...              ...          ...
# 68480  68481           257   39.66                0            0
# 68481  68482           378   50.00                0            0
# 68482  68483            41   48.00                0            0
# 68483  68484           140   62.00                0            0
# 68484  68485           180   54.50            45000            0
#
#        exterior_condition  fireplaces  frontage  garage_spaces  \
# 0                       4           0     14.00              0
# 1                       4           0     14.91              0
# 2                       4           0     17.66              1
# 3                       4           0     19.25              0
# 4                       4           0     16.00              0
# ...                   ...         ...       ...            ...
# 68480                   3           0     36.50              2
# 68481                   2           0     14.73              0
# 68482                   5           0     14.00              0
# 68483                   4           0     14.00              0
# 68484                   3           0     14.00              0
#
#        geographic_ward  ...  number_of_rooms  number_stories  quality_grade  \
# 0                   59  ...                8               3            NaN
# 1                   13  ...                6               2            NaN
# 2                   17  ...                6               2            NaN
# 3                   23  ...                6               2            NaN
# 4                   40  ...                6               2            NaN
# ...                ...  ...              ...             ...            ...
# 68480                9  ...                8               0            NaN
# 68481               31  ...                6               2            NaN
# 68482               39  ...                6               2            NaN
# 68483               47  ...                7               2            NaN
# 68484               25  ...                6               2            NaN
#
#        sale_price  taxable_building  taxable_land  total_area  \
# 0           90000             78887         22513      938.00
# 1           52500             40800          7200     1044.00
# 2          154000             88400         15600     1686.53
# 3           65900             53986         11214     2165.62
# 4           47000             56185          9915     1264.00
# ...           ...               ...           ...         ...
# 68480      257500            320553         73247     6213.00
# 68481      275000            221500         60900      736.50
# 68482       57000             68569         16231      672.00
# 68483       73150            101430         43470      868.00
# 68484      150000             73899         48801      763.00
#
#        total_livable_area  year_built  zip_code
# 0                    1344        1895     19144
# 1                    1190        1940     19140
# 2                    1633        1940     19141
# 3                    1320        1940     19124
# 4                     960        1920     19142
# ...                   ...         ...       ...
# 68480                1360        1950     19118
# 68481                1635        1875     19125
# 68482                 900        1925     19148
# 68483                1722        1920     19130
# 68484                1070        1920     19134
#
# [68485 rows x 25 columns]

# %% [markdown]
# ## Single Linear Regression

# %%
for column in df.columns:
    if column != 'sale_price'and abs(df['sale_price'].corr(df[column]))>0.1:
        sns.regplot(data=df, x=column, y='sale_price')
        plt.show()

# %%
# Select categorical data values and reshape to arrays
X = df['total_livable_area'].values.reshape(-1,1)
y = df['sale_price'].values.reshape(-1, 1)

print(X.shape)
print(y.shape)
# Out:
# (68485, 1)
# (68485, 1)

# %%
# Use train_test_split to create training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create the model using LinearRegression
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {roundtraining_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.10972065312489909
# Testing Score: 0.09290244871430409

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([[172926.83470058],
#        [220624.77591583],
#        [146827.96120544],
#        ...,
#        [209375.26147827],
#        [137378.36907789],
#        [231424.30977589]])

# %%
plt.scatter(model.predict(X_train), y_train - model.predict(X_train), c="blue", label="Training Data")
plt.scatter(model.predict(X_test), y_test - model.predict(X_test), c="orange", label="Testing Data")
plt.legend()
plt.title("Residual Plot")
plt.show()

# %%
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10]}")
# Out:
# First 10 Predictions:   [[172926.83470058]
#  [220624.77591583]
#  [146827.96120544]
#  [125678.87406283]
#  [300721.31871126]
#  [206225.39743576]
#  [204875.45570325]
#  [-85362.0167858 ]
#  [220624.77591583]
#  [165727.14546054]]
# First 10 Actual labels: [[ 60000]
#  [182000]
#  [  9909]
#  [128700]
#  [285000]
#  [230000]
#  [132000]
#  [499900]
#  [220000]
#  [ 95000]]

# %% [markdown]
# ## Multiple Linear Regression

# %%
data = df.copy()

# %%
X = df[]
# Out:
#   File "<ipython-input-12-85756782b0c2>", line 1
#     X = df[]
#            ^
# SyntaxError: invalid syntax
